# %%
num = list(map(int,input().split()))
max = 0

for i in num :
    if max == 0 or max < i:
        max = i
        
print ("Max = ", max)
# Out:
# 10 20 30 25 15
# Max =  30

# %%
#encryption 
str = input("input of encryption: ")
str = str.split()
str.reverse()
str = ' '.join(str)
en = ""

for i in range(len(str)) :
    c = str[i]
    if (c != ' ') :
        ac = ord(c)
        ac += 1
        c = chr(ac)
    en += c
    
print("result of enrcryption: ", en)

#decrptyion 
str = input("input of decryption: ")
str = str.split()
str.reverse()
str = ' '.join(str)
de = ""

for i in range(len(str)) :
    c = str[i]
    if (c != ' ') :
        ac = ord(c)
        ac -= 1
        c = chr(ac)
    de += c
    
print("result of decryption: ", de)
# Out:
# input of encryption: abc def
# result of enrcryption:  efg bcd
# input of decryption: efg bcd
# result of decryption:  abc def

# %%
book = {}

for i in range(10) :
    name = input('name: ').title()
    phone = input('phone: ')
    book[name] = phone
    
print("search name or phone?")
print("1. name")
print("2. phone")

while True:
    menu = input("menu: ")
    temp_book = dict(map(reversed, book.items()))
    
    if menu == '1':
        name = input('name?: ').title()
        phone = book.get(name)
        print('phone number of', f'{name}', 'is', phone)
        
    elif menu == '2': 
        phone = input('phone?: ').title()
        name = temp_book.get(phone)
        print(f'{phone}', 'is phone number of', name)
# Out:
# name: aaa
# phone: 111
# name: bbb
# phone: 222
# name: ccc
# phone: 333
# name: ddd
# phone: 444
# name: eee
# phone: 555
# name: fff
# phone: 666
# name: ggg
# phone: 777
# name: hhh
# phone: 888
# name: iii
# phone: 999
# name: jjj
# phone: 000
# search name or phone?
# 1. name
# 2. phone
# menu: 1
# name?: eee
# phone number of Eee is 555
# menu: 1
# name?: ggg
# phone number of Ggg is 777
# menu: 2
# phone?: 333
# 333 is phone number of Ccc
# menu: 2
# phone?: 888
# 888 is phone number of Hhh
